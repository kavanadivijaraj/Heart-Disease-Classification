# %%
#calling all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data information

# %%
# dataset
df=pd.read_csv("heart.csv")

# %% [raw]
# Data source: https://www.kaggle.com/c/heart-disease-uci/data

# %% [raw]
# Data Description :-
#
# age - age in years
# sex - (1 = male; 0 = female)
# cp - chest pain type
# trestbps - resting blood pressure (in mm Hg on admission to the hospital)
# chol - serum cholestoral in mg/dl
# fbs - (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# restecg - resting electrocardiographic results
# thalach - maximum heart rate achieved
# exang - exercise induced angina (1 = yes; 0 = no)
# oldpeak - ST depression induced by exercise relative to rest
# slope - the slope of the peak exercise ST segment
# ca - number of major vessels (0-3) colored by flourosopy
# thal - 3 = normal; 6 = fixed defect; 7 = reversable defect
# target - have disease or not (1=yes, 0=no)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#column names of the dataset
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#renaming columns for better understanding
df = df.rename(columns={'cp':'Chest Pain' , 'trestbps':'BP','chol':'cholesterol','fbs':'fasting blood sugar','restecg':'Resting ECG','thalach':'Max Heart Rate','exang':'exercise induced angina','thal':'Thalassemia','num       ':'object'})
df
# Out:
#      age  sex  Chest Pain   BP  cholesterol  fasting blood sugar  Resting ECG  \
# 0     63    1           3  145          233                    1            0
# 1     37    1           2  130          250                    0            1
# 2     41    0           1  130          204                    0            0
# 3     56    1           1  120          236                    0            1
# 4     57    0           0  120          354                    0            1
# ..   ...  ...         ...  ...          ...                  ...          ...
# 298   57    0           0  140          241                    0            1
# 299   45    1           3  110          264                    0            1
# 300   68    1           0  144          193                    1            1
# 301   57    1           0  130          131                    0            1
# 302   57    0           1  130          236                    0            0
#
#      Max Heart Rate  exercise induced angina  oldpeak  slope  ca  Thalassemia  \
# 0               150                        0      2.3      0   0            1
# 1               187                        0      3.5      0   0            2
# 2               172                        0      1.4      2   0            2
# 3               178                        0      0.8      2   0            2
# 4               163                        1      0.6      2   0            2
# ..              ...                      ...      ...    ...  ..          ...
# 298             123                        1      0.2      1   0            3
# 299             132                        0      1.2      1   0            3
# 300             141                        0      3.4      1   2            3
# 301             115                        1      1.2      1   1            3
# 302             174                        0      0.0      1   1            2
#
#      target
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 298       0
# 299       0
# 300       0
# 301       0
# 302       0
#
# [303 rows x 14 columns]

# %% [markdown]
# # Understanding data

# %%
#display first 5 rows
df.head()
# Out:
#    age  sex  Chest Pain   BP  cholesterol  fasting blood sugar  Resting ECG  \
# 0   63    1           3  145          233                    1            0
# 1   37    1           2  130          250                    0            1
# 2   41    0           1  130          204                    0            0
# 3   56    1           1  120          236                    0            1
# 4   57    0           0  120          354                    0            1
#
#    Max Heart Rate  exercise induced angina  oldpeak  slope  ca  Thalassemia  \
# 0             150                        0      2.3      0   0            1
# 1             187                        0      3.5      0   0            2
# 2             172                        0      1.4      2   0            2
# 3             178                        0      0.8      2   0            2
# 4             163                        1      0.6      2   0            2
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
#display last 5 rows
df.tail()
# Out:
#      age  sex  Chest Pain   BP  cholesterol  fasting blood sugar  Resting ECG  \
# 298   57    0           0  140          241                    0            1
# 299   45    1           3  110          264                    0            1
# 300   68    1           0  144          193                    1            1
# 301   57    1           0  130          131                    0            1
# 302   57    0           1  130          236                    0            0
#
#      Max Heart Rate  exercise induced angina  oldpeak  slope  ca  Thalassemia  \
# 298             123                        1      0.2      1   0            3
# 299             132                        0      1.2      1   0            3
# 300             141                        0      3.4      1   2            3
# 301             115                        1      1.2      1   1            3
# 302             174                        0      0.0      1   1            2
#
#      target
# 298       0
# 299       0
# 300       0
# 301       0
# 302       0

# %%
#size of dataset
df.shape
# Out:
# (303, 14)

# %%
#column names of dataset after renaming
df.columns
# Out:
# Index(['age', 'sex', 'Chest Pain', 'BP', 'cholesterol', 'fasting blood sugar',
#        'Resting ECG', 'Max Heart Rate', 'exercise induced angina', 'oldpeak',
#        'slope', 'ca', 'Thalassemia', 'target'],
#       dtype='object')

# %%
#information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      303 non-null    int64
#  1   sex                      303 non-null    int64
#  2   Chest Pain               303 non-null    int64
#  3   BP                       303 non-null    int64
#  4   cholesterol              303 non-null    int64
#  5   fasting blood sugar      303 non-null    int64
#  6   Resting ECG              303 non-null    int64
#  7   Max Heart Rate           303 non-null    int64
#  8   exercise induced angina  303 non-null    int64
#  9   oldpeak                  303 non-null    float64
#  10  slope                    303 non-null    int64
#  11  ca                       303 non-null    int64
#  12  Thalassemia              303 non-null    int64
#  13  target                   303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
#statistical description of dataset
df.describe()
# Out:
#               age         sex  Chest Pain          BP  cholesterol  \
# count  303.000000  303.000000  303.000000  303.000000   303.000000
# mean    54.366337    0.683168    0.966997  131.623762   246.264026
# std      9.082101    0.466011    1.032052   17.538143    51.830751
# min     29.000000    0.000000    0.000000   94.000000   126.000000
# 25%     47.500000    0.000000    0.000000  120.000000   211.000000
# 50%     55.000000    1.000000    1.000000  130.000000   240.000000
# 75%     61.000000    1.000000    2.000000  140.000000   274.500000
# max     77.000000    1.000000    3.000000  200.000000   564.000000
#
#        fasting blood sugar  Resting ECG  Max Heart Rate  \
# count           303.000000   303.000000      303.000000
# mean              0.148515     0.528053      149.646865
# std               0.356198     0.525860       22.905161
# min               0.000000     0.000000       71.000000
# 25%               0.000000     0.000000      133.500000
# 50%               0.000000     1.000000      153.000000
# 75%               0.000000     1.000000      166.000000
# max               1.000000     2.000000      202.000000
#
#        exercise induced angina     oldpeak       slope          ca  \
# count               303.000000  303.000000  303.000000  303.000000
# mean                  0.326733    1.039604    1.399340    0.729373
# std                   0.469794    1.161075    0.616226    1.022606
# min                   0.000000    0.000000    0.000000    0.000000
# 25%                   0.000000    0.000000    1.000000    0.000000
# 50%                   0.000000    0.800000    1.000000    0.000000
# 75%                   1.000000    1.600000    2.000000    1.000000
# max                   1.000000    6.200000    2.000000    4.000000
#
#        Thalassemia      target
# count   303.000000  303.000000
# mean      2.313531    0.544554
# std       0.612277    0.498835
# min       0.000000    0.000000
# 25%       2.000000    0.000000
# 50%       2.000000    1.000000
# 75%       3.000000    1.000000
# max       3.000000    1.000000

# %%
#checking null values in dataset
df.isnull().sum()
# Out:
# age                        0
# sex                        0
# Chest Pain                 0
# BP                         0
# cholesterol                0
# fasting blood sugar        0
# Resting ECG                0
# Max Heart Rate             0
# exercise induced angina    0
# oldpeak                    0
# slope                      0
# ca                         0
# Thalassemia                0
# target                     0
# dtype: int64

# %%
#data types of datase values
df.dtypes
# Out:
# age                          int64
# sex                          int64
# Chest Pain                   int64
# BP                           int64
# cholesterol                  int64
# fasting blood sugar          int64
# Resting ECG                  int64
# Max Heart Rate               int64
# exercise induced angina      int64
# oldpeak                    float64
# slope                        int64
# ca                           int64
# Thalassemia                  int64
# target                       int64
# dtype: object

# %%
#unique values in data set
df.nunique()
# Out:
# age                         41
# sex                          2
# Chest Pain                   4
# BP                          49
# cholesterol                152
# fasting blood sugar          2
# Resting ECG                  3
# Max Heart Rate              91
# exercise induced angina      2
# oldpeak                     40
# slope                        3
# ca                           5
# Thalassemia                  4
# target                       2
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [raw]
# As the target variable("Target" column) and many other associated variables are categorical, Classification type of Supervised Machine Learning algorithm is adopted in this project.

# %%
#correlation of dataset
df.corr()
# Out:
#                               age       sex  Chest Pain        BP  \
# age                      1.000000 -0.098447   -0.068653  0.279351
# sex                     -0.098447  1.000000   -0.049353 -0.056769
# Chest Pain              -0.068653 -0.049353    1.000000  0.047608
# BP                       0.279351 -0.056769    0.047608  1.000000
# cholesterol              0.213678 -0.197912   -0.076904  0.123174
# fasting blood sugar      0.121308  0.045032    0.094444  0.177531
# Resting ECG             -0.116211 -0.058196    0.044421 -0.114103
# Max Heart Rate          -0.398522 -0.044020    0.295762 -0.046698
# exercise induced angina  0.096801  0.141664   -0.394280  0.067616
# oldpeak                  0.210013  0.096093   -0.149230  0.193216
# slope                   -0.168814 -0.030711    0.119717 -0.121475
# ca                       0.276326  0.118261   -0.181053  0.101389
# Thalassemia              0.068001  0.210041   -0.161736  0.062210
# target                  -0.225439 -0.280937    0.433798 -0.144931
#
#                          cholesterol  fasting blood sugar  Resting ECG  \
# age                         0.213678             0.121308    -0.116211
# sex                        -0.197912             0.045032    -0.058196
# Chest Pain                 -0.076904             0.094444     0.044421
# BP                          0.123174             0.177531    -0.114103
# cholesterol                 1.000000             0.013294    -0.151040
# fasting blood sugar         0.013294             1.000000    -0.084189
# Resting ECG                -0.151040            -0.084189     1.000000
# Max Heart Rate             -0.009940            -0.008567     0.044123
# exercise induced angina     0.067023             0.025665    -0.070733
# oldpeak                     0.053952             0.005747    -0.058770
# slope                      -0.004038            -0.059894     0.093045
# ca                          0.070511             0.137979    -0.072042
# Thalassemia                 0.098803            -0.032019    -0.011981
# target                     -0.085239            -0.028046     0.137230
#
#                          Max Heart Rate  exercise induced angina   oldpeak  \
# age                           -0.398522                 0.096801  0.210013
# sex                           -0.044020                 0.141664  0.096093
# Chest Pain                     0.295762                -0.394280 -0.149230
# BP                            -0.046698                 0.067616  0.193216
# cholesterol                   -0.009940                 0.067023  0.053952
# fasting blood sugar           -0.008567                 0.025665  0.005747
# Resting ECG                    0.044123                -0.070733 -0.058770
# Max Heart Rate                 1.000000                -0.378812 -0.344187
# exercise induced angina       -0.378812                 1.000000  0.288223
# oldpeak                       -0.344187                 0.288223  1.000000
# slope                          0.386784                -0.257748 -0.577537
# ca                            -0.213177                 0.115739  0.222682
# Thalassemia                   -0.096439                 0.206754  0.210244
# target                         0.421741                -0.436757 -0.430696
#
#                             slope        ca  Thalassemia    target
# age                     -0.168814  0.276326     0.068001 -0.225439
# sex                     -0.030711  0.118261     0.210041 -0.280937
# Chest Pain               0.119717 -0.181053    -0.161736  0.433798
# BP                      -0.121475  0.101389     0.062210 -0.144931
# cholesterol             -0.004038  0.070511     0.098803 -0.085239
# fasting blood sugar     -0.059894  0.137979    -0.032019 -0.028046
# Resting ECG              0.093045 -0.072042    -0.011981  0.137230
# Max Heart Rate           0.386784 -0.213177    -0.096439  0.421741
# exercise induced angina -0.257748  0.115739     0.206754 -0.436757
# oldpeak                 -0.577537  0.222682     0.210244 -0.430696
# slope                    1.000000 -0.080155    -0.104764  0.345877
# ca                      -0.080155  1.000000     0.151832 -0.391724
# Thalassemia             -0.104764  0.151832     1.000000 -0.344029
# target                   0.345877 -0.391724    -0.344029  1.000000

# %%
correlation_matrix=df.corr()
plt.figure(figsize=(30,20))
sns.heatmap(correlation_matrix, annot = True, linewidths = 1)
plt.show()

# %%
#mean values of dataset
df.mean()
# Out:
# age                         54.366337
# sex                          0.683168
# Chest Pain                   0.966997
# BP                         131.623762
# cholesterol                246.264026
# fasting blood sugar          0.148515
# Resting ECG                  0.528053
# Max Heart Rate             149.646865
# exercise induced angina      0.326733
# oldpeak                      1.039604
# slope                        1.399340
# ca                           0.729373
# Thalassemia                  2.313531
# target                       0.544554
# dtype: float64

# %%
df.head(2)
# Out:
#    age  sex  Chest Pain   BP  cholesterol  fasting blood sugar  Resting ECG  \
# 0   63    1           3  145          233                    1            0
# 1   37    1           2  130          250                    0            1
#
#    Max Heart Rate  exercise induced angina  oldpeak  slope  ca  Thalassemia  \
# 0             150                        0      2.3      0   0            1
# 1             187                        0      3.5      0   0            2
#
#    target
# 0       1
# 1       1

# %%
df.hist(figsize=(15,10));

# %%
plt.bar(df['target'].unique(), df['target'].value_counts())
plt.xticks([0, 1])
plt.xlabel('Target distribution')
plt.ylabel('Count')
plt.title('Target distribution counts')
# Out:
# Text(0.5, 1.0, 'Target distribution counts')

# %% [markdown]
# Target data set is balanced.

# %%
df.head(2)
# Out:
#    age  sex  Chest Pain   BP  cholesterol  fasting blood sugar  Resting ECG  \
# 0   63    1           3  145          233                    1            0
# 1   37    1           2  130          250                    0            1
#
#    Max Heart Rate  exercise induced angina  oldpeak  slope  ca  Thalassemia  \
# 0             150                        0      2.3      0   0            1
# 1             187                        0      3.5      0   0            2
#
#    target
# 0       1
# 1       1

# %% [markdown]
# # Machine Learning

# %% [markdown]
# Splitting dataset into train set and test set

# %%
y = dataset['target']
X = dataset.drop(['target'], axis = 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Decision Tree Classifier method
from sklearn.tree import DecisionTreeClassifier
DTC = DecisionTreeClassifier()
DTC.fit(X_train,y_train)
DTC_prediction = DTC.predict(X_test)
DTC_accuracy = DTC.score(X_test,y_test)
print("Accuracy of Decision Tree Classifier on this dataset is ",DTC_accuracy)
# Out:
# Accuracy of Decision Tree Classifier on this dataset is  0.8032786885245902

# %%
# Random Forest Classification method
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(n_estimators = 1000, random_state = 1)
RF.fit(X_train, y_train)
RF_prediction = RF.predict(X_test)
RF_accuracy = RF.score(X_test,y_test)
print("Accuracy of Random Forest Classifier on this dataset is ",RF_accuracy)
# Out:
# Accuracy of Random Forest Classifier on this dataset is  0.8524590163934426

# %% [markdown]
# # Conclusion

# %% [markdown]
# Dataset was trained and tested with maximum scores, using below 2 methods of classification, with accuracy rate:
#
# Decision Tree Classifier: 80%
# Random Forest Classifier: 85%
#
# Random Tree Classifier thus, is the best model to predict Heart Disease Analysis
